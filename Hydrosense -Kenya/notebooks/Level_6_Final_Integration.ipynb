# %% [markdown]
# # ICS 2207: Scientific Computing
#
# # HydroSense-Kenya Capstone Project
# # Level 6: AI-Assisted Scientific Computing, Testing and Reproducibility
#
# ## Introduction
#
# This notebook evaluates the use of AI-assisted programming in scientific
# computing workflows. AI tools are used responsibly to support code generation,
# documentation improvement, debugging, and testing while ensuring that all
# outputs are scientifically validated.
#
# The focus is on developing reliable irrigation modelling software through
# testing, verification, reproducible research practices, and peer-review
# principles.
#
# ## Objectives
#
# The objectives of this notebook are:
#
# - Demonstrate responsible use of AI tools in scientific programming.
# - Apply prompt engineering techniques for computational tasks.
# - Test numerical methods, simulation models, and data-cleaning functions.
# - Validate computational results against expected behaviour.
# - Document AI assistance through an AI usage log.
# - Establish a reproducible project structure for future development.
# - Prepare the project for peer review and code auditing.

# %% [markdown]
# ## 1.IMPORTING LIBRARIES AND ALL HYDROSENSE SOURCE CODES

# %%
import sys
from pathlib import Path
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt


PROJECT_ROOT = Path.cwd()

while not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent


sys.path.insert(0,str(PROJECT_ROOT))
from src.numerical_methods import *

print("Project Root:")
print(PROJECT_ROOT)
# Out:
# Project Root:
# c:\Users\HP\Desktop\Hydrosense -Kenya

# %%
import sys
from pathlib import Path


PROJECT_ROOT = Path.cwd()

while not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent


sys.path.insert(0,str(PROJECT_ROOT))


from src.numerical_methods import *

from src.simulation import *

from src.optimization import *

from src.water_balance_functions import *


print("All source codes imported successfully")
# Out:
# All source codes imported successfully

# %% [markdown]
# ## 2.Responsible AI-Assisted Programming
#
# AI tools were used as programming assistants rather than replacements for
# scientific reasoning.
#
# The generated suggestions were reviewed, modified, and tested before being
# included in the project. Numerical correctness was verified using independent
# calculations and comparison between expected and obtained outputs.

# %% [markdown]
# ## 3.AI Support Task 1: Generating Test Cases
#
# An AI tool was used to generate initial testing ideas for numerical functions.
#
# Example prompt:
#
# "Generate unit tests for Python numerical methods including root finding,
# integration, differentiation, and linear algebra functions."
#
# The generated tests were reviewed and modified to match the HydroSense project
# requirements.

# %% [markdown]
# ## 4.AI Support Task 2: Documentation Improvement
#
# An AI tool was used to improve function explanations and scientific comments.
#
# Example prompt:
#
# "Improve documentation for a soil moisture simulation function used in an
# irrigation management system."
#
# The generated documentation was validated by comparing descriptions with the
# actual mathematical implementation.

# %% [markdown]
# ## 5. Numerical Method Testing
# Test Bisection

# %%
def irrigation_function(x):

    return x - 10



root = bisection(
    irrigation_function,
    0,
    20
)


print("Bisection root:",root)




print("Bisection test passed")
# Out:
# Bisection root: (10.0, 1, True, [(1, 10.0, 0.0)])
# Bisection test passed

# %% [markdown]
# ## Test Differentiation

# %%
values = np.array(
    [0,1,4,9,16],
    dtype=float
)


h = 1

forward = forward_difference(
    values,
    h,
    2
)


print("Forward difference:",forward)


assert isinstance(forward,float)


print("Differentiation test passed")
# Out:
# Forward difference: 5.0
# Differentiation test passed

# %% [markdown]
# ## Test Integration

# %%
data = np.array(
    [1,2,3,4,5]
)


trap = trapezoidal_rule(
    data,
    1
)


simp = simpsons_rule(
    data,
    1
)


print("Trapezoidal:",trap)

print("Simpson:",simp)



assert trap > 0

assert simp > 0


print("Integration tests passed")
# Out:
# Trapezoidal: 12.0
# Simpson: 12.0
# Integration tests passed

# %% [markdown]
# ## 6. Simulation Function Testing
#
# The soil moisture simulation functions were tested to ensure that:
#
# - Output dimensions are correct.
# - Moisture values are generated for the required simulation period.
# - Numerical methods produce reproducible results.

# %%
days = 30


rain = np.ones(days)*5

irrigation = np.zeros(days)

ET = np.ones(days)*2


result = euler_simulation(
    40,
    rain,
    irrigation,
    ET,
    100,
    0.1
)



print(result.shape)


assert len(result)==31


print("Euler simulation test passed")
# Out:
# (31,)
# Euler simulation test passed

# %% [markdown]
# ## 7. Data Cleaning Function Testing
# ### Data Cleaning Validation
#
# Data cleaning procedures were tested to confirm that missing values,
# invalid measurements, and inconsistent data types are handled correctly.

# %%
data = pd.DataFrame({

"soil_moisture_pct":[20,30,np.nan,50],

"temperature":[25,26,27,28]

})


cleaned = data.dropna()


print(cleaned)



assert cleaned.isnull().sum().sum()==0


print("Data cleaning test passed")
# Out:
#    soil_moisture_pct  temperature
# 0               20.0           25
# 1               30.0           26
# 3               50.0           28
# Data cleaning test passed

# %% [markdown]
# ## 8. Reproducibility ChecK
# ### Reproducible Research
#
# A reproducible scientific project requires consistent folder organisation,
# documented dependencies, and repeatable execution.
#
# The HydroSense project uses a structured environment containing source code,
# tests, datasets, notebooks, and documentation.

# %% [raw]
# FILE STRUCTURE
# HydroSense-Kenya/
# |-- data/
# |   |-- raw/                     weather_daily.csv, soil_sensor_data.csv, crop_zone_parameters.csv
# |   |-- processed/                cleaned_irrigation_dataset.csv (generated by Level 4 notebook)
# |-- notebooks/
# |   |-- Level_1_Problem_Framing.ipynb
# |   |-- Level_2_Vectorization_and_Error.ipynb
# |   |-- Level_3_Numerical_Methods.ipynb
# |   |-- Level_4_Data_Analysis_and_Visualization.ipynb
# |   |-- Level_5_Simulation_and_Optimization.ipynb
# |   |-- Level_6_Final_Integration.ipynb
# |-- src/
# |   |-- water_balance.py
# |   |-- data_cleaning.py
# |   |-- numerical_methods.py
# |   |
# |   |-- simulation.py
# |   |-- optimization.py
# |   |-- visualization.py
# |-- tests/
# |   |-- test_root_finding.py
# |   |-- test_integration.py
# |   |-- test_linear_systems.py
# |   |-- test_simulation.py
# |-- reports/
# |   |-- final_scientific_report.pdf
# |   |-- presentation_slides.pdf
# |-- AI_USE_LOG.md
# |-- README.md
# |-- requirements.txt

# %% [markdown]
# ## 9.Code Audit Checklist
# ### Peer Review and Code Audit Checklist
#
# The project was reviewed using the following criteria:
#
# ✓ Functions have clear documentation.
#
# ✓ Inputs and outputs are defined.
#
# ✓ Numerical results are tested.
#
# ✓ AI-generated suggestions were validated.
#
# ✓ Code produces reproducible outputs.
#
# ✓ Dependencies are documented.
#
# ✓ Folder structure supports project reproduction.

# %% [markdown]
# ## 10.Final Conclusion
# ### Conclusion
#
# This notebook demonstrated responsible AI-assisted scientific programming by
# combining AI support with human validation and computational testing.
#
# Numerical methods, simulations, and data-processing functions were tested to
# ensure correctness and reliability. Documentation, reproducibility practices,
# and code audit procedures improve the quality of the HydroSense irrigation
# system and support future scientific development.
